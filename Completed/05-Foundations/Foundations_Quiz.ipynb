# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# *Your Answer:* displays a list of all variables with their types and values

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# *Your Answer:*

# %% [markdown]
# ## My Hobbies
#
#
# *   Soccer
# *   Running
# *   Playing Guitar

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd ls
# Out:
# '/content'

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
with open('hello.txt', 'w') as f:
    f.write('Hello World')

with open('hello.txt', 'r') as f:
    print(f.read())
# Out:
# Hello World

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
import pandas as pd

df = pd.DataFrame({'name': ['Ken', 'Bob', 'Alice', 'Tom', 'Mike', 'Leo', 'Jerry', 'Maddy', 'Eve'],
                   'age': [21, 22, 23, 24, 21, 22, 23, 24, 25]})

df.to_csv('students.csv', index=False)
df = pd.read_csv('students.csv')
df.head()
# Out:
#     name  age
# 0    Ken   21
# 1    Bob   22
# 2  Alice   23
# 3    Tom   24
# 4   Mike   21

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# *Your Answer:* ctrl + M D

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
len?

#Signature: len(obj, /)
#Docstring: Return the number of items in a container.
#Type:      builtin_function_or_method

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
# %timeit [i**2 for i in range(1000)]
# %timeit np.arange(1000)**2
# Out:
# 88.8 µs ± 28.7 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.68 µs ± 87.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# *Your Answer:*
#
# When using both Markdown and code, you can display your code while also providing explanations about how it works. This helps to clarify the purpose and logic behind the code, making it easier for others to understand. Additionally, combining text and code makes the notebook more readable and easier to edit for future use.
